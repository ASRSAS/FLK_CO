# %%
# !pip install azure-ai-documentintelligence==1.0.0b1
# !pip install azure-ai-formrecognizer
# !pip install python-dotenv
# Out:
# Requirement already satisfied: azure-ai-documentintelligence==1.0.0b1 in /usr/local/lib/python3.10/dist-packages (1.0.0b1)
# Requirement already satisfied: isodate<1.0.0,>=0.6.1 in /usr/local/lib/python3.10/dist-packages (from azure-ai-documentintelligence==1.0.0b1) (0.6.1)
# Requirement already satisfied: azure-core<2.0.0,>=1.28.0 in /usr/local/lib/python3.10/dist-packages (from azure-ai-documentintelligence==1.0.0b1) (1.29.6)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.10/dist-packages (from azure-core<2.0.0,>=1.28.0->azure-ai-documentintelligence==1.0.0b1) (3.7.1)
# Requirement already satisfied: requests>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from azure-core<2.0.0,>=1.28.0->azure-ai-documentintelligence==1.0.0b1) (2.31.0)
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from azure-core<2.0.0,>=1.28.0->azure-ai-documentintelligence==1.0.0b1) (1.16.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from azure-core<2.0.0,>=1.28.0->azure-ai-documentintelligence==1.0.0b1) (4.9.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5.0,>=3.0->azure-core<2.0.0,>=1.28.0->azure-ai-documentintelligence==1.0.0b1) (3.6)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<5.0,>=3.0->azure-core<2.0.0,>=1.28.0->azure-ai-documentintelligence==1.0.0b1) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5.0,>=3.0->azure-core<2.0.0,>=1.28.0->azure-ai-documentintelligence==1.0.0b1) (1.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.28.0->azure-ai-documentintelligence==1.0.0b1) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.28.0->azure-ai-documentintelligence==1.0.0b1) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.28.0->azure-ai-documentintelligence==1.0.0b1) (2023.11.17)
# Requirement already satisfied: azure-ai-formrecognizer in /usr/local/lib/python3.10/dist-packages (3.3.2)
# Requirement already satisfied: azure-core<2.0.0,>=1.23.0 in /usr/local/lib/python3.10/dist-packages (from azure-ai-formrecognizer) (1.29.6)
# Requirement already satisfied: msrest>=0.6.21 in /usr/local/lib/python3.10/dist-packages (from azure-ai-formrecognizer) (0.7.1)
# Requirement already satisfied: azure-common~=1.1 in /usr/local/lib/python3.10/dist-packages (from azure-ai-formrecognizer) (1.1.28)
# Requirement already satisfied: typing-extensions>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from azure-ai-formrecognizer) (4.9.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.10/dist-packages (from azure-core<2.0.0,>=1.23.0->azure-ai-formrecognizer) (3.7.1)
# Requirement already satisfied: requests>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from azure-core<2.0.0,>=1.23.0->azure-ai-formrecognizer) (2.31.0)
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from azure-core<2.0.0,>=1.23.0->azure-ai-formrecognizer) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from msrest>=0.6.21->azure-ai-formrecognizer) (2023.11.17)
# Requirement already satisfied: isodate>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from msrest>=0.6.21->azure-ai-formrecognizer) (0.6.1)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from msrest>=0.6.21->azure-ai-formrecognizer) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5.0,>=3.0->azure-core<2.0.0,>=1.23.0->azure-ai-formrecognizer) (3.6)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<5.0,>=3.0->azure-core<2.0.0,>=1.23.0->azure-ai-formrecognizer) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5.0,>=3.0->azure-core<2.0.0,>=1.23.0->azure-ai-formrecognizer) (1.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.23.0->azure-ai-formrecognizer) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.23.0->azure-ai-formrecognizer) (2.0.7)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.5.0->msrest>=0.6.21->azure-ai-formrecognizer) (3.2.2)
# Collecting python-dotenv
#   Downloading python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.0.0

# %%
# !pip install azure-functions
# !pip install azure-storage-blob==12.6.0
# Out:
# Collecting azure-functions
#   Downloading azure_functions-1.18.0-py3-none-any.whl (173 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 173.2/173.2 kB 2.0 MB/s eta 0:00:00
# Installing collected packages: azure-functions
# Successfully installed azure-functions-1.18.0
# Collecting azure-storage-blob==12.6.0
#   Downloading azure_storage_blob-12.6.0-py2.py3-none-any.whl (328 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 328.9/328.9 kB 2.8 MB/s eta 0:00:00
# Requirement already satisfied: azure-core<2.0.0,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from azure-storage-blob==12.6.0) (1.29.6)
# Requirement already satisfied: msrest>=0.6.10 in /usr/local/lib/python3.10/dist-packages (from azure-storage-blob==12.6.0) (0.7.1)
# Requirement already satisfied: cryptography>=2.1.4 in /usr/local/lib/python3.10/dist-packages (from azure-storage-blob==12.6.0) (41.0.7)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.10/dist-packages (from azure-core<2.0.0,>=1.9.0->azure-storage-blob==12.6.0) (3.7.1)
# Requirement already satisfied: requests>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from azure-core<2.0.0,>=1.9.0->azure-storage-blob==12.6.0) (2.31.0)
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from azure-core<2.0.0,>=1.9.0->azure-storage-blob==12.6.0) (1.16.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from azure-core<2.0.0,>=1.9.0->azure-storage-blob==12.6.0) (4.9.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=2.1.4->azure-storage-blob==12.6.0) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from msrest>=0.6.10->azure-storage-blob==12.6.0) (2023.11.17)
# Requirement already satisfied: isodate>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from msrest>=0.6.10->azure-storage-blob==12.6.0) (0.6.1)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from msrest>=0.6.10->azure-storage-blob==12.6.0) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5.0,>=3.0->azure-core<2.0.0,>=1.9.0->azure-storage-blob==12.6.0) (3.6)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<5.0,>=3.0->azure-core<2.0.0,>=1.9.0->azure-storage-blob==12.6.0) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5.0,>=3.0->azure-core<2.0.0,>=1.9.0->azure-storage-blob==12.6.0) (1.2.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=2.1.4->azure-storage-blob==12.6.0) (2.21)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.9.0->azure-storage-blob==12.6.0) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.9.0->azure-storage-blob==12.6.0) (2.0.7)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.5.0->msrest>=0.6.10->azure-storage-blob==12.6.0) (3.2.2)
# Installing collected packages: azure-storage-blob
# Successfully installed azure-storage-blob-12.6.0

# %%
import os, io, json, copy
from azure.core.exceptions import AzureError
from azure.storage.blob import BlobClient
from urllib.parse import urlparse

def blob_name_and_url_dict(blob_service_client, container_name) -> dict:
    """
    This function takes in a blob service client and a container name and returns
    a dictionary containing the blob details indexed by the container name, file type, and then file name or url.
    :param blob_service_client: BlobServiceClient object
    :param container_name: Name of the container to be accessed
    :return: Dictionary containing the blob details indexed by the container name, file type, and then file name or url
    """
    # Create an empty dictionary to store the blob details
    blob_name_and_url_dict = {}

    try:
        # Create the BlobContainerClien object so we can connect to the blob storage container based on the container name
        container_client = blob_service_client.get_container_client(container_name)
        print(f"The container {container_name} is being accessed.")
    except Exception as e:
        print(f"ERROR: Could not access the container {container_name}.")
        print(e)

    try:
        # List all blobs in the container
        blob_list = container_client.list_blobs()

        # If the container name is not in the dictionary, add it
        if container_name not in blob_name_and_url_dict:
            blob_name_and_url_dict[container_name] = {}

        # Loop through each blob in the container
        for blob in blob_list:
            blob_client = container_client.get_blob_client(blob)
            print(f"The file {blob.name} located at {blob_client.url} is being added to the blob list.")

            # Get the file extension
            _, file_extension = os.path.splitext(blob.name)

            # Now you can use file_extension in your dictionary
            blob_file_dict = {
                'file_name': blob.name,
                'blob_url': blob_client.url
            }

            # If the file type is not in the dictionary, add it
            if file_extension not in blob_name_and_url_dict[container_name]:
                blob_name_and_url_dict[container_name][file_extension] = {}

            # Add the dictionary to the dictionary associated with the file type
            blob_name_and_url_dict[container_name][file_extension][blob.name] = blob_file_dict

        return blob_name_and_url_dict
    except Exception as e:
        print(f"ERROR: Could not list the blobs in the container {container_name}.")
        print(e)


def doc_intel_pdf(document_analysis_client, doc_intel_model, file_name, blob_url, poller_result_or_dict_flag) -> dict:
    '''
    Function to analyze a PDF document using the Document Intelligence service based
    on the url of the blob containing the document - this is the raw document.
    The url must contain a SAS token with read permissions.

    :param document_analysis_client: DocumentAnalysisClient object
    :param doc_intel_model: Document Intelligence model to use
    :param file_name: Name of the file to be analyzed
    :param blob_url: URL of the blob to be analyzed
    :param poller_result_or_dict_flag: Flag to return the poller result ('result')  or the dictionary ('dict) or both ('both)
    :return: Document Intelligence results as the result object, a dictionary, or both
    '''
    try:
        # Extract the blob name from the blob URL
        blob_name = urlparse(blob_url).path.split('/')[-1]

        _, file_extension = os.path.splitext(blob_name)
        if file_extension == '.pdf':
            # Analyze the document using the Document Intelligence service
            doc_intel_pdf_poller = document_analysis_client.begin_analyze_document_from_url(
                                            doc_intel_model,
                                            document_url=blob_url
                                            )
            doc_intel_pdf_result = doc_intel_pdf_poller.result()
            doc_intel_pdf_result_dict = doc_intel_pdf_result.to_dict()

            print(f'File {file_name} was analyzed using the Document Intelligence service.')

            # Return the result based on the flag poller_result_or_dict_flag
            if poller_result_or_dict_flag == 'result':
                return doc_intel_pdf_result
            if poller_result_or_dict_flag == 'dict':
                return doc_intel_pdf_result_dict
            if poller_result_or_dict_flag == 'both':
                return doc_intel_pdf_result, doc_intel_pdf_result_dict

        else:
            print(f'File {file_name} is not a PDF according to the file extension.')
            return None

    except Exception as e:
        print(f'Error: {e}')
        return None


def local_file_write(data, text_or_json_flag=str, file_path=str, file_name_with_extension=str) -> None:
    '''
    :param raw_result: the raw result from the document intelligence service
    :param result_dict: the dictionary of results from the document intelligence service
    :param text_or_json_flag: a flag to determine if the file should be written as a text file or a json file
    :return: None
    '''
    try:
        if text_or_json_flag == 'text':
            with open(file_path + '/' + file_name_with_extension, 'w', encoding='utf-8') as f:
                f.write(str(data))
                print('File successfully written to ' + file_path + '/' + file_name_with_extension)
        elif text_or_json_flag == 'json':
            with open(file_path + '/' + file_name_with_extension, 'w') as f:
                json.dump(data, f)
                print('File successfully written to ' + file_path + '/' + file_name_with_extension)
        else:
            print('''Please specify if you want to write a text or json file by setting the text_or_json_flag parameter to 'json' or 'text'.''')

    except Exception as e:
        print(e)

    return None


def local_file_read(file_path: str, text_or_json_flag: str):
    '''
    :param file_path: the path to the file to read
    :param text_or_json_flag: a flag to determine if the file is a text file or a json file
    :return: the contents of the file as either a dictionary or raw text
    '''
    try:
        with open(file_path, 'r', encoding='utf-8') as f:
            if text_or_json_flag == 'text':
                return f.read()
            elif text_or_json_flag == 'json':
                return json.load(f)
            else:
                print('''Please specify if you want to read a text or json file by setting the text_or_json_flag parameter to 'json' or 'text'.''')
                return None
    except Exception as e:
        print(e)
        return None


def write_to_blob(object_to_upload, blob_service_client, container_name=str, virtual_directory_name=str, file_name=str, json_dump_flag=bool):
    '''
    This function will write a file to a blob storage container; uses json.dumps to convert to json if json_dump_flag is True.
    :param object_to_upload: The object to upload to the blob storage container
    :param blob_service_client: The blob service client object; raw_blob_service_client, processed_blob_service_client, or final_blob_service_client in this exercise
    :param container_name: The name of the container to upload to; raw_container_name, processed_container_name, or final_container_name in this exercise
    :param virtual_directory_name: The name of the virtual directory to upload to; raw_results or dictionaries in this exercise
    :param file_name: The name of the file to upload, string format
    :param json_dump_flag: A boolean flag to indicate if the object should be converted to json before uploading
    '''
    blob_name = str(container_name + '/' + virtual_directory_name + '/' + file_name)
    blob_client = blob_service_client.get_blob_client(container=container_name, blob=blob_name)
    print(blob_client) # Only needed for debugging
    if json_dump_flag == True:
        try:
            json_object_to_upload = json.dumps(object_to_upload)
            blob_client.upload_blob(json_object_to_upload, blob_type="BlockBlob")
            print(f'Uploaded {file_name} to {blob_name}')
        except Exception as e:
            print(f'Error uploading {file_name} to {blob_name} with the following Error: {e}')

    else:
        try:
            str_object_to_upload = str(object_to_upload)
            blob_client.upload_blob(str_object_to_upload, blob_type="BlockBlob")
            print(f'Uploaded {file_name} to {blob_name}')
        except Exception as e:
            print(f'Error uploading {file_name} to {blob_name} with the following Error: {e}')


def load_blobs_iterator(blob_dict, file_type=None, file_name=None):
    """
    Generator function to load blobs from Azure Blob Storage.

    Parameters:
    blob_dict (dict): A dictionary with blob names as keys and blob URLs as values.
    file_type (str, optional): The file type to filter blobs by. Only blobs with this file type will be loaded. Defaults to None.
    file_name (str, optional): The file name to filter blobs by. Only the blob with this file name will be loaded. Defaults to None.

    Yields:
    str: The content of a blob.

    Example usage:
    dictionary_of_processed_blobs = fn.blob_name_and_url_dict()

    for blob_content in load_blobs(dictionary_of_processed_blobs):
        # Now blob_content contains the actual content of a blob
        # You can process it here
        print(blob_content)
    """

    # Iterate over all blobs in the dictionary
    for blob_name, blob_url in blob_dict.items():
        # If a file type is specified, skip blobs that don't match the file type
        if file_type and not blob_name.endswith(file_type):
            continue
        # If a file name is specified, skip blobs that don't match the file name
        if file_name and blob_name != file_name:
            continue

        try:
            # Create a blob client for the current blob
            blob_client = BlobClient.from_blob_url(blob_url)
            # Download the blob's content
            blob_content = blob_client.download_blob().readall()

            # Yield the blob's content
            yield blob_content
        except AzureError as e:
            print(f"Failed to download blob: {blob_name}. Error: {e}")


def load_blob(blob_dict, container_name=None, file_type=None, file_name=None):
    """
    Load a single blob from a nested dictionary of blob names and URLs.

    Parameters:
    blob_dict (dict): A nested dictionary where keys are container names, file types, and blob names, and values are blob details.
    file_type (str, optional): The file type to filter blobs by. Blobs not of this file type will be ignored.
    file_name (str, optional): A specific blob name to load. If provided, only this blob will be loaded.
    container_name (str, optional): A specific container name to load blobs from. If provided, only blobs from this container will be loaded.

    Returns:
    bytes: The content of the blob.

    Example usage:
    blob_dict = {"container1": {".txt": {"blob1": {"file_name": "blob1", "blob_url": "url1"}}}}
    load_blob(blob_dict, file_type=".txt", file_name="blob1", container_name="container1")

    .txt
    blob_content_string = blob_content.decode('utf-8')

    .json

    """

    # If container_name is provided and it does not exist in the dictionary, return None
    if container_name and container_name not in blob_dict:
        print(f'container_name:{container_name} not found in blob_dict')
        return None
    # If container_name is provided, iterate over just this container, otherwise over all containers in the dictionary
    for container_name, container_dict in ([(container_name, blob_dict[container_name])] if container_name else blob_dict.items()):
        # If file_type is provided and it does not exist in the current container's dictionary, skip this container
        if file_type and file_type not in container_dict:
            print(f'file_type:{file_type} not found in container_dict')
            continue
        # If file_type is provided, iterate over all blobs in the file_type dictionary, otherwise in the container's dictionary
        for blob_name, blob_details in (container_dict[file_type] if file_type else container_dict).items():
            # If file_name is provided and blob_name is not equal to it, skip this blob
            if file_name and blob_name != file_name:
                print(f'file_name:{file_name} not found in blob_dict {blob_dict}')
                continue

            try:
                # Create a BlobClient for the blob
                print(f'blob_details:{blob_details}')
                blob_client = BlobClient.from_blob_url(blob_details['blob_url'])
                # Download the blob and read all its content
                blob_content = blob_client.download_blob().readall()

                if file_type == '.json':
                    # Convert the bytes to a file-like object
                    blob_file = io.BytesIO(blob_content)
                    # Load the JSON document from the file
                    blob_content_obj = json.load(blob_file)
                    # Return the Python object
                    return blob_content_obj

                if file_type == '.txt':
                    # Convert the bytes to a string
                    blob_content_string = blob_content.decode('utf-8')
                    # Return the string
                    return blob_content_string

                # Return the blob content
                return blob_content
            except AzureError as e:
                print(f"Failed to download blob: {e}")
                return None

    # If no blob was found that matches the criteria, return None
    return None


def print_keys(data, parent_key='', printed_keys=set()):
    """
    Recursively prints all keys in a nested dictionary or list.

    Args:
        data (dict or list): The data to print keys from.
        parent_key (str, optional): The parent key to prepend to each key. Defaults to ''.
        printed_keys (set, optional): The set of already printed keys. Defaults to set().

    Returns:
        None
    """
    # if data is a dictionary
    if isinstance(data, dict):
        # iterate over each key-value pair in the dictionary
        for k, v in data.items():
            # create the current key by appending the parent key and the current key
            current_key = f"{parent_key}.{k}" if parent_key else k
            # if the current key has not been printed before, print it and add it to the printed keys set
            if current_key not in printed_keys:
                print(current_key)
                printed_keys.add(current_key)
            # recursively call the function with the value of the current key and the current key as the parent key
            print_keys(v, current_key, printed_keys)
    # if data is a list
    elif isinstance(data, list):
        # iterate over each element in the list
        for v in data:
            # recursively call the function with the current element and the parent key
            print_keys(v, parent_key, printed_keys)


def select_keys(original_dict, keys_to_select, current_path=''):
    """
    This function selects specific keys from a dictionary, including nested dictionaries and lists of dictionaries.
    It also keeps track of the path of nested keys in the format 'key1.key2.key3'.

    Parameters:
    original_dict (dict): The original dictionary from which keys are to be selected.
    keys_to_select (list): A list of keys that need to be selected from the original dictionary.
    current_path (str): The current path of nested keys. Default is an empty string.

    Returns:
    new_dict (dict): A new dictionary containing only the selected keys from the original dictionary.
    """

    # Initialize a new dictionary to store the selected keys
    new_dict = {}

    # Iterate over each key-value pair in the original dictionary
    for key, value in original_dict.items():

        # Construct the new key path
        new_key_path = current_path + '.' + key if current_path else key

        # If the key or the new key path is in the list of keys to select, add it to the new dictionary
        if key in keys_to_select or new_key_path in keys_to_select:
            new_dict[key] = value

        # If the value is a dictionary, recursively call the function for nested keys
        if isinstance(value, dict):
            new_dict[key] = select_keys(value, keys_to_select, new_key_path)

        # If the value is a list, iterate over each item in the list
        elif isinstance(value, list):
            new_list = []

            # If the item is a dictionary, recursively call the function for nested keys
            for item in value:
                if isinstance(item, dict):
                    new_list.append(select_keys(item, keys_to_select, new_key_path))

            # If the new list is not empty, add it to the new dictionary
            if new_list:
                new_dict[key] = new_list

    # Return the new dictionary with the selected keys
    return new_dict


def process_data(data, keys_to_remove):
    """
    This function processes a data structure (dictionary or list) and removes specified keys.
    It also moves 'page_number' from 'bounding_regions' to the parent level for 'tables', 'paragraphs', and 'cells'.

    Parameters:
    data (dict or list): The original data structure from which keys are to be removed.
    keys_to_remove (list): A list of keys that need to be removed from the data structure.

    Returns:
    data (dict or list): The processed data structure with the specified keys removed.
    """

    # If the data is a dictionary, iterate over each key-value pair
    if isinstance(data, dict):
        for key, value in list(data.items()):

            # If the key is in the list of keys to remove, delete it from the dictionary
            if key in keys_to_remove:
                del data[key]
                continue

            # If the key is 'tables', 'paragraphs', or 'cells', process the 'bounding_regions'
            if key in ['tables', 'paragraphs', 'cells']:
                for item in value:
                    if 'bounding_regions' in item:
                        for region in item['bounding_regions']:
                            if 'page_number' in region:
                                # Move 'page_number' from 'bounding_regions' to the parent level
                                item['page_number'] = region['page_number']
                        # Delete 'bounding_regions' from the item
                        del item['bounding_regions']

            # Recursively call the function for nested data structures
            data[key] = process_data(value, keys_to_remove)

    # If the data is a list, iterate over each item in the list
    elif isinstance(data, list):
        for i in range(len(data)):
            # Recursively call the function for each item in the list
            data[i] = process_data(data[i], keys_to_remove)

    # Return the processed data structure
    return data

# %%
# import libraries"
import os
from azure.core.credentials import AzureKeyCredential
from azure.ai.documentintelligence import DocumentIntelligenceClient
# Import the Necessary Python Libraries

# Import standard and non-Azure libraries
import os
import json
from dotenv import load_dotenv

# Import the Azure SDK libraries
from azure.storage.blob import BlobServiceClient
from azure.ai.formrecognizer import DocumentAnalysisClient
from azure.core.credentials import AzureKeyCredential

# Import the custom functions

from azure.core.credentials import AzureKeyCredential
from azure.ai.formrecognizer import DocumentAnalysisClient

# %%
"""
Remember to remove the key from your code when you're done, and never post it publicly. For production, use
secure methods to store and access your credentials. For more information, see
https://docs.microsoft.com/en-us/azure/cognitive-services/cognitive-services-security?tabs=command-line%2Ccsharp#environment-variables-and-application-configuration
"""
endpoint =""
key = ""

# sample document
formUrl = "https://raw.githubusercontent.com/ASRSAS/FLK_CO/fa7f914ddde1dec03a3fa1dfe24fa748d5030756/Financials%20ABC%20Company_wip%201%201.pdf"

document_analysis_client = DocumentAnalysisClient(
    endpoint=endpoint, credential=AzureKeyCredential(key)
)

# %%
document_analysis_client

# %%
poller = document_analysis_client.begin_analyze_document_from_url("prebuilt-invoice", formUrl)
invoices = poller.result()
doc_intel_pdf_result = poller.result()
doc_intel_pdf_result_dict = doc_intel_pdf_result.to_dict()

# %%
keys_to_select = [
'content',
'pages',
'pages.page_number',
'pages.lines',
'pages.lines.content',
'pages.words',
'pages.words.content',
'pages.selection_marks',
'pages.selection_marks.state',
'pages.selection_marks.confidence',
'paragraphs',
'paragraphs.role',
'paragraphs.content',
'paragraphs.bounding_regions.page_number',
'tables',
'tables.row_count',
'tables.column_count',
'tables.cells',
'tables.cells.kind',
'tables.cells.row_index',
'tables.cells.column_index',
'tables.cells.row_span',
'tables.cells.column_span',
'tables.cells.content',
'tables.cells.bounding_regions.page_number',
'tables.bounding_regions.page_number'
]

# Create a new dictionary with only the keys we want to work with as defined in the keys_to_select list
# the format of the keys is that which is generated by the fn.print_keys function
intermediate_dnd_pdf_working_dict = select_keys(doc_intel_pdf_result_dict, keys_to_select)
# Only necessary if you want to see the keys in the new dictionary
# fn.print_keys(intermediate_dnd_pdf_working_dict)

# %%
keys_to_remove = ['polygon', 'spans', 'span', 'styles']
final_dnd_pdf_working_dict = process_data(intermediate_dnd_pdf_working_dict, keys_to_remove)
# Only necessary if you want to see the keys in the final dictionary structure
print_keys(final_dnd_pdf_working_dict)
# Out:
# content
# pages
# pages.page_number
# pages.lines
# pages.lines.content
# pages.words
# pages.words.content
# pages.selection_marks
# paragraphs
# tables
# tables.row_count
# tables.column_count
# tables.cells
# tables.cells.kind
# tables.cells.row_index
# tables.cells.column_index
# tables.cells.row_span
# tables.cells.column_span
# tables.cells.content
# tables.cells.page_number
# tables.page_number
# documents
# documents.bounding_regions
# documents.fields
# documents.fields.InvoiceDate
# documents.fields.InvoiceDate.content
# documents.fields.InvoiceDate.bounding_regions
# documents.fields.Items
# documents.fields.Items.value
# documents.fields.Items.value.value
# documents.fields.Items.value.value.Amount
# documents.fields.Items.value.value.Amount.value
# documents.fields.Items.value.value.Amount.content
# documents.fields.Items.value.value.Amount.bounding_regions
# documents.fields.Items.value.value.Description
# documents.fields.Items.value.value.Description.content
# documents.fields.Items.value.value.Description.bounding_regions
# documents.fields.Items.value.content
# documents.fields.Items.value.bounding_regions
# documents.fields.Items.content
# documents.fields.VendorName
# documents.fields.VendorName.content
# documents.fields.VendorName.bounding_regions

# %%
final_dnd_pdf_working_dict
# Out:
# {'content': "ABC Company Inc.\nBalance Sheet\nDecember 31, 2022\nAssets\n2022\n2021\n2020\n2019\nCurrent Assets\nCash\n$ 141,943\n$ 412,649\n$ 265,566\n$ 6,280\nAccounts Receivable\n2,217,666\n1,817,617\n2,675,115\n1,398,480\nInventory -note 1\n780,613\n1,389,798\n531,366\n1,257,936\nDue from related companies\n3,128,917\n2,709,071\n2,706,871\n2,495,367\nTotal Current Assets\n6,255,901\n6,329,135\n6,178,918\n5,158,063\nCapital Assets\nEquipment\n398,866\n451,716\n470,208\n443,481\nTotal Capital Assets\n398,866\n451,716\n470,208\n443,481\nTotal Assets\n$ 6,668,005\n$ 6,780,851\n$ 6,649,126\n$ 5,601,544\nLiabilities and Shareholder's Equity\nCurrent Liabilities\nBank Indebtedness\n$ 61,769\n$ 298,001\n-\n-\nAccounts payable\n414,676\n608,139\n585,946\n404,779\nGovernment remittances\n197,142\n127,001\n178,339\n120,628\nIncome taxes payable\n159,062\n160,390\n248,674\n3,603\nFuture income taxes\n89,000\n91,000\n105,000\n95,000\nDue to shareholders\n72,663\n80,388\n80,446\n99,393\nDue to related companies\n2,197,792\n750,042\n1,401,542\n-\nTotal Current Liabilities\n994,312\n3,264,710\n1,948,447\n2,423,946\nTotal Liabilities\n994,312\n3,264,710\n1,948,447\n2,423,946\nShareholders' Equity\nCapital stock\n100\n100\n100\n100\nRetained Earnings\n5,673,593\n3,516,041\n4,700,579\n3,177,498\nTotal Shareholder's Equity\n5,673,693\n3,516,141\n4,700,679\n3,177,598\nTotal Liabilities and\n$ 6,668,005\n$ 6,780,851\n$ 6,649,126\n$ 5,601,544\nShareholder's Equity\nABC Company Inc.\nStatement of Income and Retained Earnings\nDecember 31, 2022\n2022\n2021\n2020\n2019\nSales\n$ 15,747,983\n$ 14,016,607\n$ 13,640,756\n$ 11,566,631\nCost of Sales\n10,997,073\n9,988,215\n10,106,015\n8,120,069\nGross Profit\n4,750,910\n4,028,392\n3,534,741\n3,446,562\nExpenses\nAdvertising\n59,329\n30,562\n22,542\n34,812\nAmortization\n104,787\n110,955\n108,595\n72,339\nAutomotive\n473,127\n376,058\n328,939\n257,485\nBank Charges\n15,276\n22,371\n62,571\n16,302\nInsurance\n74,386\n71,638\n55,243\n60,411\nManagement Salaries\n421,465\n429,807\n412,792\n428,211\nOffice\n25,601\n26,361\n43,964\n40,211\nProfessional Fees\n13,200\n15,063\n14,253\n11,800\nRent\n267,333\n188,000\n180,000\n180,000\nShop-Utilities, Repairs\n114,764\n92,034\n68,966\n99,570\nTelephone\n21,332\n18,975\n19,427\n21,305\nTravel\n201,189\n136,810\n136,153\n102,920\nUniforms\n71,769\n85,402\n71,640\n72,134\nTotal Expenses\n1,863,558\n1,604,036\n1,525,085\n1,397,500\nIncome before other item\n2,887,352\n2,424,356\n2,009,656\n2,049,062\nand taxes\nOther income\nGain on foreign exchange\n11,400\n-\n-\n-\nIncome before taxes\n2,898,752\n2,424,356\n2,009,656\n2,049,062\nIncome taxes (recovery)\n741,200\n608,894\n486,575\n478,481\nNet Income\n2,157,552\n1,815,462\n1,523,081\n1,570,581\nRetained Earnings,\n3,516,041\n4,700,579\n3,177,498\n4,606,917\nbeginning of year\nDividends\n(3,000,000)\n(3,000,000)\n-\n-\nRetained Earnings, end of\n$ 5,673,593\n$ 3,516,041\n$ 4,700,579\n$ 3,177,498\nyear\nABC Company Inc.\nNotes to the financial statement\nDecember 31, 2022\n1- Inventory\nInventory consists of the following\n2022\n2021\n2020\n2019\nMaterials and supplies\n$ 38,647\n$ 37,560\n$ 47,848\n$ 68,467\nWork-in-progress\n741,966\n1,352,238\n483,518\n1,189,469\nInventory, end of year\n780,613\n1,389,798\n$ 531,366\n$ 1,257,936",
#  'pages': [{'page_number': 1,
#    'lines': [{'content': 'ABC Company Inc.'},
#     {'content': 'Balance Sheet'},
#     {'content': 'December 31, 2022'},
#     {'content': 'Assets'},
#     {'content': '2022'},
#     {'content': '2021'},
#     {'content': '2020'},
#     {'content': '2019'},
#     {'content': 'Current Assets'},
#     {'content': 'Cash'},
#     {'content': '$ 141,943'},
#     {'content': '$ 412,649'},
#     {'content': '$ 265,566'},
#     {'content': '$ 6,280'},
#     {'content': 'Accounts Receivable'},
#     {'content': '2,217,666'},
#     {'content': '1,817,617'},
#     {'content': '2,675,115'},
#     {'content': '1,398,480'},
#     {'content': 'Inventory -note 1'},
#     {'content': '780,613'},
#     {'content': '1,389,798'},
#     {'content': '531,366'},
#     {'content': '1,257,936'},
#     {'content': 'Due from related companies'},
#     {'content': '3,128,917'},
#     {'content': '2,709,071'},
#     {'content': '2,706,871'},
#     {'content': '2,495,367'},
#     {'content': 'Total Current Assets'},
#     {'content': '6,255,901'},
#     {'content': '6,329,135'},
#     {'content': '6,178,918'},
#     {'content': '5,158,063'},
#     {'content': 'Capital Assets'},
#     {'content': 'Equipment'},
#     {'content': '398,866'},
#     {'content': '451,716'},
#     {'content': '470,208'},
#     {'content': '443,481'},
#     {'content': 'Total Capital Assets'},
#     {'content': '398,866'},
#     {'content': '451,716'},
#     {'content': '470,208'},
#     {'content': '443,481'},
#     {'content': 'Total Assets'},
#     {'content': '$ 6,668,005'},
#     {'content': '$ 6,780,851'},
#     {'content': '$ 6,649,126'},
#     {'content': '$ 5,601,544'},
#     {'content': "Liabilities and Shareholder's Equity"},
#     {'content': 'Current Liabilities'},
#     {'content': 'Bank Indebtedness'},
#     {'content': '$ 61,769'},
#     {'content': '$ 298,001'},
#     {'content': '-'},
#     {'content': '-'},
#     {'content': 'Accounts payable'},
#     {'content': '414,676'},
#     {'content': '608,139'},
#     {'content': '585,946'},
#     {'content': '404,779'},
#     {'content': 'Government remittances'},
#     {'content': '197,142'},
#     {'content': '127,001'},
#     {'content': '178,339'},
#     {'content': '120,628'},
#     {'content': 'Income taxes payable'},
#     {'content': '159,062'},
#     {'content': '160,390'},
#     {'content': '248,674'},
#     {'content': '3,603'},
#     {'content': 'Future income taxes'},
#     {'content': '89,000'},
#     {'content': '91,000'},
#     {'content': '105,000'},
#     {'content': '95,000'},
#     {'content': 'Due to shareholders'},
#     {'content': '72,663'},
#     {'content': '80,388'},
#     {'content': '80,446'},
#     {'content': '99,393'},
#     {'content': 'Due to related companies'},
#     {'content': '2,197,792'},
#     {'content': '750,042'},
#     {'content': '1,401,542'},
#     {'content': '-'},
#     {'content': 'Total Current Liabilities'},
#     {'content': '994,312'},
#     {'content': '3,264,710'},
#     {'content': '1,948,447'},
#     {'content': '2,423,946'},
#     {'content': 'Total Liabilities'},
#     {'content': '994,312'},
#     {'content': '3,264,710'},
#     {'content': '1,948,447'},
#     {'content': '2,423,946'},
#     {'content': "Shareholders' Equity"},
#     {'content': 'Capital stock'},
#     {'content': '100'},
#     {'content': '100'},
#     {'content': '100'},
#     {'content': '100'},
#     {'content': 'Retained Earnings'},
#     {'content': '5,673,593'},
#     {'content': '3,516,041'},
#     {'content': '4,700,579'},
#     {'content': '3,177,498'},
#     {'content': "Total Shareholder's Equity"},
#     {'content': '5,673,693'},
#     {'content': '3,516,141'},
#     {'content': '4,700,679'},
#     {'content': '3,177,598'},
#     {'content': 'Total Liabilities and'},
#     {'content': '$ 6,668,005'},
#     {'content': '$ 6,780,851'},
#     {'content': '$ 6,649,126'},
#     {'content': '$ 5,601,544'},
#     {'content': "Shareholder's Equity"}],
#    'words': [{'content': 'ABC'},
#     {'content': 'Company'},
#     {'content': 'Inc.'},
#     {'content': 'Balance'},
#     {'content': 'Sheet'},
#     {'content': 'December'},
#     {'content': '31,'},
#     {'content': '2022'},
#     {'content': 'Assets'},
#     {'content': '2022'},
#     {'content': '2021'},
#     {'content': '2020'},
#     {'content': '2019'},
#     {'content': 'Current'},
#     {'content': 'Assets'},
#     {'content': 'Cash'},
#     {'content': '$'},
#     {'content': '141,943'},
#     {'content': '$'},
#     {'content': '412,649'},
#     {'content': '$'},
#     {'content': '265,566'},
#     {'content': '$'},
#     {'content': '6,280'},
#     {'content': 'Accounts'},
#     {'content': 'Receivable'},
#     {'content': '2,217,666'},
#     {'content': '1,817,617'},
#     {'content': '2,675,115'},
#     {'content': '1,398,480'},
#     {'content': 'Inventory'},
#     {'content': '-note'},
#     {'content': '1'},
#     {'content': '780,613'},
#     {'content': '1,389,798'},
#     {'content': '531,366'},
#     {'content': '1,257,936'},
#     {'content': 'Due'},
#     {'content': 'from'},
#     {'content': 'related'},
#     {'content': 'companies'},
#     {'content': '3,128,917'},
#     {'content': '2,709,071'},
#     {'content': '2,706,871'},
#     {'content': '2,495,367'},
#     {'content': 'Total'},
#     {'content': 'Current'},
#     {'content': 'Assets'},
#     {'content': '6,255,901'},
#     {'content': '6,329,135'},
#     {'content': '6,178,918'},
#     {'content': '5,158,063'},
#     {'content': 'Capital'},
#     {'content': 'Assets'},
#     {'content': 'Equipment'},
#     {'content': '398,866'},
#     {'content': '451,716'},
#     {'content': '470,208'},
#     {'content': '443,481'},
#     {'content': 'Total'},
#     {'content': 'Capital'},
#     {'content': 'Assets'},
#     {'content': '398,866'},
#     {'content': '451,716'},
#     {'content': '470,208'},
#     {'content': '443,481'},
#     {'content': 'Total'},
#     {'content': 'Assets'},
#     {'content': '$'},
#     {'content': '6,668,005'},
#     {'content': '$'},
#     {'content': '6,780,851'},
#     {'content': '$'},
#     {'content': '6,649,126'},
#     {'content': '$'},
#     {'content': '5,601,544'},
#     {'content': 'Liabilities'},
#     {'content': 'and'},
#     {'content': "Shareholder's"},
#     {'content': 'Equity'},
#     {'content': 'Current'},
#     {'content': 'Liabilities'},
#     {'content': 'Bank'},
#     {'content': 'Indebtedness'},
#     {'content': '$'},
#     {'content': '61,769'},
#     {'content': '$'},
#     {'content': '298,001'},
#     {'content': '-'},
#     {'content': '-'},
#     {'content': 'Accounts'},
#     {'content': 'payable'},
#     {'content': '414,676'},
#     {'content': '608,139'},
#     {'content': '585,946'},
#     {'content': '404,779'},
#     {'content': 'Government'},
#     {'content': 'remittances'},
#     {'content': '197,142'},
#     {'content': '127,001'},
#     {'content': '178,339'},
#     {'content': '120,628'},
#     {'content': 'Income'},
#     {'content': 'taxes'},
#     {'content': 'payable'},
#     {'content': '159,062'},
#     {'content': '160,390'},
#     {'content': '248,674'},
#     {'content': '3,603'},
#     {'content': 'Future'},
#     {'content': 'income'},
#     {'content': 'taxes'},
#     {'content': '89,000'},
#     {'content': '91,000'},
#     {'content': '105,000'},
#     {'content': '95,000'},
#     {'content': 'Due'},
#     {'content': 'to'},
#     {'content': 'shareholders'},
#     {'content': '72,663'},
#     {'content': '80,388'},
#     {'content': '80,446'},
#     {'content': '99,393'},
#     {'content': 'Due'},
#     {'content': 'to'},
#     {'content': 'related'},
#     {'content': 'companies'},
#     {'content': '2,197,792'},
#     {'content': '750,042'},
#     {'content': '1,401,542'},
#     {'content': '-'},
#     {'content': 'Total'},
#     {'content': 'Current'},
#     {'content': 'Liabilities'},
#     {'content': '994,312'},
#     {'content': '3,264,710'},
#     {'content': '1,948,447'},
#     {'content': '2,423,946'},
#     {'content': 'Total'},
#     {'content': 'Liabilities'},
#     {'content': '994,312'},
#     {'content': '3,264,710'},
#     {'content': '1,948,447'},
#     {'content': '2,423,946'},
#     {'content': "Shareholders'"},
#     {'content': 'Equity'},
#     {'content': 'Capital'},
#     {'content': 'stock'},
#     {'content': '100'},
#     {'content': '100'},
#     {'content': '100'},
#     {'content': '100'},
#     {'content': 'Retained'},
#     {'content': 'Earnings'},
#     {'content': '5,673,593'},
#     {'content': '3,516,041'},
#     {'content': '4,700,579'},
#     {'content': '3,177,498'},
#     {'content': 'Total'},
#     {'content': "Shareholder's"},
#     {'content': 'Equity'},
#     {'content': '5,673,693'},
#     {'content': '3,516,141'},
#     {'content': '4,700,679'},
#     {'content': '3,177,598'},
#     {'content': 'Total'},
#     {'content': 'Liabilities'},
#     {'content': 'and'},
#     {'content': '$'},
#     {'content': '6,668,005'},
#     {'content': '$'},
#     {'content': '6,780,851'},
#     {'content': '$'},
#     {'content': '6,649,126'},
#     {'content': '$'},
#     {'content': '5,601,544'},
#     {'content': "Shareholder's"},
#     {'content': 'Equity'}],
#    'selection_marks': []},
#   {'page_number': 2,
#    'lines': [{'content': 'ABC Company Inc.'},
#     {'content': 'Statement of Income and Retained Earnings'},
#     {'content': 'December 31, 2022'},
#     {'content': '2022'},
#     {'content': '2021'},
#     {'content': '2020'},
#     {'content': '2019'},
#     {'content': 'Sales'},
#     {'content': '$ 15,747,983'},
#     {'content': '$ 14,016,607'},
#     {'content': '$ 13,640,756'},
#     {'content': '$ 11,566,631'},
#     {'content': 'Cost of Sales'},
#     {'content': '10,997,073'},
#     {'content': '9,988,215'},
#     {'content': '10,106,015'},
#     {'content': '8,120,069'},
#     {'content': 'Gross Profit'},
#     {'content': '4,750,910'},
#     {'content': '4,028,392'},
#     {'content': '3,534,741'},
#     {'content': '3,446,562'},
#     {'content': 'Expenses'},
#     {'content': 'Advertising'},
#     {'content': '59,329'},
#     {'content': '30,562'},
#     {'content': '22,542'},
#     {'content': '34,812'},
#     {'content': 'Amortization'},
#     {'content': '104,787'},
#     {'content': '110,955'},
#     {'content': '108,595'},
#     {'content': '72,339'},
#     {'content': 'Automotive'},
#     {'content': '473,127'},
#     {'content': '376,058'},
#     {'content': '328,939'},
#     {'content': '257,485'},
#     {'content': 'Bank Charges'},
#     {'content': '15,276'},
#     {'content': '22,371'},
#     {'content': '62,571'},
#     {'content': '16,302'},
#     {'content': 'Insurance'},
#     {'content': '74,386'},
#     {'content': '71,638'},
#     {'content': '55,243'},
#     {'content': '60,411'},
#     {'content': 'Management Salaries'},
#     {'content': '421,465'},
#     {'content': '429,807'},
#     {'content': '412,792'},
#     {'content': '428,211'},
#     {'content': 'Office'},
#     {'content': '25,601'},
#     {'content': '26,361'},
#     {'content': '43,964'},
#     {'content': '40,211'},
#     {'content': 'Professional Fees'},
#     {'content': '13,200'},
#     {'content': '15,063'},
#     {'content': '14,253'},
#     {'content': '11,800'},
#     {'content': 'Rent'},
#     {'content': '267,333'},
#     {'content': '188,000'},
#     {'content': '180,000'},
#     {'content': '180,000'},
#     {'content': 'Shop-Utilities, Repairs'},
#     {'content': '114,764'},
#     {'content': '92,034'},
#     {'content': '68,966'},
#     {'content': '99,570'},
#     {'content': 'Telephone'},
#     {'content': '21,332'},
#     {'content': '18,975'},
#     {'content': '19,427'},
#     {'content': '21,305'},
#     {'content': 'Travel'},
#     {'content': '201,189'},
#     {'content': '136,810'},
#     {'content': '136,153'},
#     {'content': '102,920'},
#     {'content': 'Uniforms'},
#     {'content': '71,769'},
#     {'content': '85,402'},
#     {'content': '71,640'},
#     {'content': '72,134'},
#     {'content': 'Total Expenses'},
#     {'content': '1,863,558'},
#     {'content': '1,604,036'},
#     {'content': '1,525,085'},
#     {'content': '1,397,500'},
#     {'content': 'Income before other item'},
#     {'content': '2,887,352'},
#     {'content': '2,424,356'},
#     {'content': '2,009,656'},
#     {'content': '2,049,062'},
#     {'content': 'and taxes'},
#     {'content': 'Other income'},
#     {'content': 'Gain on foreign exchange'},
#     {'content': '11,400'},
#     {'content': '-'},
#     {'content': '-'},
#     {'content': '-'},
#     {'content': 'Income before taxes'},
#     {'content': '2,898,752'},
#     {'content': '2,424,356'},
#     {'content': '2,009,656'},
#     {'content': '2,049,062'},
#     {'content': 'Income taxes (recovery)'},
#     {'content': '741,200'},
#     {'content': '608,894'},
#     {'content': '486,575'},
#     {'content': '478,481'},
#     {'content': 'Net Income'},
#     {'content': '2,157,552'},
#     {'content': '1,815,462'},
#     {'content': '1,523,081'},
#     {'content': '1,570,581'},
#     {'content': 'Retained Earnings,'},
#     {'content': '3,516,041'},
#     {'content': '4,700,579'},
#     {'content': '3,177,498'},
#     {'content': '4,606,917'},
#     {'content': 'beginning of year'},
#     {'content': 'Dividends'},
#     {'content': '(3,000,000)'},
#     {'content': '(3,000,000)'},
#     {'content': '-'},
#     {'content': '-'},
#     {'content': 'Retained Earnings, end of'},
#     {'content': '$ 5,673,593'},
#     {'content': '$ 3,516,041'},
#     {'content': '$ 4,700,579'},
#     {'content': '$ 3,177,498'},
#     {'content': 'year'}],
#    'words': [{'content': 'ABC'},
#     {'content': 'Company'},
#     {'content': 'Inc.'},
#     {'content': 'Statement'},
#     {'content': 'of'},
#     {'content': 'Income'},
#     {'content': 'and'},
#     {'content': 'Retained'},
#     {'content': 'Earnings'},
#     {'content': 'December'},
#     {'content': '31,'},
#     {'content': '2022'},
#     {'content': '2022'},
#     {'content': '2021'},
#     {'content': '2020'},
#     {'content': '2019'},
#     {'content': 'Sales'},
#     {'content': '$'},
#     {'content': '15,747,983'},
#     {'content': '$'},
#     {'content': '14,016,607'},
#     {'content': '$'},
#     {'content': '13,640,756'},
#     {'content': '$'},
#     {'content': '11,566,631'},
#     {'content': 'Cost'},
#     {'content': 'of'},
#     {'content': 'Sales'},
#     {'content': '10,997,073'},
#     {'content': '9,988,215'},
#     {'content': '10,106,015'},
#     {'content': '8,120,069'},
#     {'content': 'Gross'},
#     {'content': 'Profit'},
#     {'content': '4,750,910'},
#     {'content': '4,028,392'},
#     {'content': '3,534,741'},
#     {'content': '3,446,562'},
#     {'content': 'Expenses'},
#     {'content': 'Advertising'},
#     {'content': '59,329'},
#     {'content': '30,562'},
#     {'content': '22,542'},
#     {'content': '34,812'},
#     {'content': 'Amortization'},
#     {'content': '104,787'},
#     {'content': '110,955'},
#     {'content': '108,595'},
#     {'content': '72,339'},
#     {'content': 'Automotive'},
#     {'content': '473,127'},
#     {'content': '376,058'},
#     {'content': '328,939'},
#     {'content': '257,485'},
#     {'content': 'Bank'},
#     {'content': 'Charges'},
#     {'content': '15,276'},
#     {'content': '22,371'},
#     {'content': '62,571'},
#     {'content': '16,302'},
#     {'content': 'Insurance'},
#     {'content': '74,386'},
#     {'content': '71,638'},
#     {'content': '55,243'},
#     {'content': '60,411'},
#     {'content': 'Management'},
#     {'content': 'Salaries'},
#     {'content': '421,465'},
#     {'content': '429,807'},
#     {'content': '412,792'},
#     {'content': '428,211'},
#     {'content': 'Office'},
#     {'content': '25,601'},
#     {'content': '26,361'},
#     {'content': '43,964'},
#     {'content': '40,211'},
#     {'content': 'Professional'},
#     {'content': 'Fees'},
#     {'content': '13,200'},
#     {'content': '15,063'},
#     {'content': '14,253'},
#     {'content': '11,800'},
#     {'content': 'Rent'},
#     {'content': '267,333'},
#     {'content': '188,000'},
#     {'content': '180,000'},
#     {'content': '180,000'},
#     {'content': 'Shop-Utilities,'},
#     {'content': 'Repairs'},
#     {'content': '114,764'},
#     {'content': '92,034'},
#     {'content': '68,966'},
#     {'content': '99,570'},
#     {'content': 'Telephone'},
#     {'content': '21,332'},
#     {'content': '18,975'},
#     {'content': '19,427'},
#     {'content': '21,305'},
#     {'content': 'Travel'},
#     {'content': '201,189'},
#     {'content': '136,810'},
#     {'content': '136,153'},
#     {'content': '102,920'},
#     {'content': 'Uniforms'},
#     {'content': '71,769'},
#     {'content': '85,402'},
#     {'content': '71,640'},
#     {'content': '72,134'},
#     {'content': 'Total'},
#     {'content': 'Expenses'},
#     {'content': '1,863,558'},
#     {'content': '1,604,036'},
#     {'content': '1,525,085'},
#     {'content': '1,397,500'},
#     {'content': 'Income'},
#     {'content': 'before'},
#     {'content': 'other'},
#     {'content': 'item'},
#     {'content': '2,887,352'},
#     {'content': '2,424,356'},
#     {'content': '2,009,656'},
#     {'content': '2,049,062'},
#     {'content': 'and'},
#     {'content': 'taxes'},
#     {'content': 'Other'},
#     {'content': 'income'},
#     {'content': 'Gain'},
#     {'content': 'on'},
#     {'content': 'foreign'},
#     {'content': 'exchange'},
#     {'content': '11,400'},
#     {'content': '-'},
#     {'content': '-'},
#     {'content': '-'},
#     {'content': 'Income'},
#     {'content': 'before'},
#     {'content': 'taxes'},
#     {'content': '2,898,752'},
#     {'content': '2,424,356'},
#     {'content': '2,009,656'},
#     {'content': '2,049,062'},
#     {'content': 'Income'},
#     {'content': 'taxes'},
#     {'content': '(recovery)'},
#     {'content': '741,200'},
#     {'content': '608,894'},
#     {'content': '486,575'},
#     {'content': '478,481'},
#     {'content': 'Net'},
#     {'content': 'Income'},
#     {'content': '2,157,552'},
#     {'content': '1,815,462'},
#     {'content': '1,523,081'},
#     {'content': '1,570,581'},
#     {'content': 'Retained'},
#     {'content': 'Earnings,'},
#     {'content': '3,516,041'},
#     {'content': '4,700,579'},
#     {'content': '3,177,498'},
#     {'content': '4,606,917'},
#     {'content': 'beginning'},
#     {'content': 'of'},
#     {'content': 'year'},
#     {'content': 'Dividends'},
#     {'content': '(3,000,000)'},
#     {'content': '(3,000,000)'},
#     {'content': '-'},
#     {'content': '-'},
#     {'content': 'Retained'},
#     {'content': 'Earnings,'},
#     {'content': 'end'},
#     {'content': 'of'},
#     {'content': '$'},
#     {'content': '5,673,593'},
#     {'content': '$'},
#     {'content': '3,516,041'},
#     {'content': '$'},
#     {'content': '4,700,579'},
#     {'content': '$'},
#     {'content': '3,177,498'},
#     {'content': 'year'}],
#    'selection_marks': []},
#   {'page_number': 3,
#    'lines': [{'content': 'ABC Company Inc.'},
#     {'content': 'Notes to the financial statement'},
#     {'content': 'December 31, 2022'},
#     {'content': '1- Inventory'},
#     {'content': 'Inventory consists of the following'},
#     {'content': '2022'},
#     {'content': '2021'},
#     {'content': '2020'},
#     {'content': '2019'},
#     {'content': 'Materials and supplies'},
#     {'content': '$ 38,647'},
#     {'content': '$ 37,560'},
#     {'content': '$ 47,848'},
#     {'content': '$ 68,467'},
#     {'content': 'Work-in-progress'},
#     {'content': '741,966'},
#     {'content': '1,352,238'},
#     {'content': '483,518'},
#     {'content': '1,189,469'},
#     {'content': 'Inventory, end of year'},
#     {'content': '780,613'},
#     {'content': '1,389,798'},
#     {'content': '$ 531,366'},
#     {'content': '$ 1,257,936'}],
#    'words': [{'content': 'ABC'},
#     {'content': 'Company'},
#     {'content': 'Inc.'},
#     {'content': 'Notes'},
#     {'content': 'to'},
#     {'content': 'the'},
#     {'content': 'financial'},
#     {'content': 'statement'},
#     {'content': 'December'},
#     {'content': '31,'},
#     {'content': '2022'},
#     {'content': '1-'},
#     {'content': 'Inventory'},
#     {'content': 'Inventory'},
#     {'content': 'consists'},
#     {'content': 'of'},
#     {'content': 'the'},
#     {'content': 'following'},
#     {'content': '2022'},
#     {'content': '2021'},
#     {'content': '2020'},
#     {'content': '2019'},
#     {'content': 'Materials'},
#     {'content': 'and'},
#     {'content': 'supplies'},
#     {'content': '$'},
#     {'content': '38,647'},
#     {'content': '$'},
#     {'content': '37,560'},
#     {'content': '$'},
#     {'content': '47,848'},
#     {'content': '$'},
#     {'content': '68,467'},
#     {'content': 'Work-in-progress'},
#     {'content': '741,966'},
#     {'content': '1,352,238'},
#     {'content': '483,518'},
#     {'content': '1,189,469'},
#     {'content': 'Inventory,'},
#     {'content': 'end'},
#     {'content': 'of'},
#     {'content': 'year'},
#     {'content': '780,613'},
#     {'content': '1,389,798'},
#     {'content': '$'},
#     {'content': '531,366'},
#     {'content': '$'},
#     {'content': '1,257,936'}],
#    'selection_marks': []}],
#  'paragraphs': [],
#  'tables': [{'row_count': 29,
#    'column_count': 5,
#    'cells': [{'kind': 'columnHeader',
#      'row_index': 0,
#      'column_index': 0,
#      'row_span': 2,
#      'column_span': 1,
#      'content': '',
#      'page_number': 1},
#     {'kind': 'columnHeader',
#      'row_index': 0,
#      'column_index': 1,
#      'row_span': 1,
#      'column_span': 4,
#      'content': 'Assets',
#      'page_number': 1},
#     {'kind': 'columnHeader',
#      'row_index': 1,
#      'column_index': 1,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '2022',
#      'page_number': 1},
#     {'kind': 'columnHeader',
#      'row_index': 1,
#      'column_index': 2,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '2021',
#      'page_number': 1},
#     {'kind': 'columnHeader',
#      'row_index': 1,
#      'column_index': 3,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '2020',
#      'page_number': 1},
#     {'kind': 'columnHeader',
#      'row_index': 1,
#      'column_index': 4,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '2019',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 2,
#      'column_index': 0,
#      'row_span': 1,
#      'column_span': 1,
#      'content': 'Current Assets',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 2,
#      'column_index': 1,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 2,
#      'column_index': 2,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 2,
#      'column_index': 3,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 2,
#      'column_index': 4,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 3,
#      'column_index': 0,
#      'row_span': 1,
#      'column_span': 1,
#      'content': 'Cash',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 3,
#      'column_index': 1,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '$ 141,943',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 3,
#      'column_index': 2,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '$ 412,649',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 3,
#      'column_index': 3,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '$ 265,566',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 3,
#      'column_index': 4,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '$ 6,280',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 4,
#      'column_index': 0,
#      'row_span': 1,
#      'column_span': 1,
#      'content': 'Accounts Receivable',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 4,
#      'column_index': 1,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '2,217,666',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 4,
#      'column_index': 2,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '1,817,617',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 4,
#      'column_index': 3,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '2,675,115',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 4,
#      'column_index': 4,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '1,398,480',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 5,
#      'column_index': 0,
#      'row_span': 1,
#      'column_span': 1,
#      'content': 'Inventory -note 1',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 5,
#      'column_index': 1,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '780,613',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 5,
#      'column_index': 2,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '1,389,798',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 5,
#      'column_index': 3,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '531,366',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 5,
#      'column_index': 4,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '1,257,936',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 6,
#      'column_index': 0,
#      'row_span': 1,
#      'column_span': 1,
#      'content': 'Due from related companies',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 6,
#      'column_index': 1,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '3,128,917',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 6,
#      'column_index': 2,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '2,709,071',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 6,
#      'column_index': 3,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '2,706,871',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 6,
#      'column_index': 4,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '2,495,367',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 7,
#      'column_index': 0,
#      'row_span': 1,
#      'column_span': 1,
#      'content': 'Total Current Assets',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 7,
#      'column_index': 1,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '6,255,901',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 7,
#      'column_index': 2,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '6,329,135',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 7,
#      'column_index': 3,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '6,178,918',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 7,
#      'column_index': 4,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '5,158,063',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 8,
#      'column_index': 0,
#      'row_span': 1,
#      'column_span': 1,
#      'content': 'Capital Assets',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 8,
#      'column_index': 1,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 8,
#      'column_index': 2,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 8,
#      'column_index': 3,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 8,
#      'column_index': 4,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 9,
#      'column_index': 0,
#      'row_span': 1,
#      'column_span': 1,
#      'content': 'Equipment',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 9,
#      'column_index': 1,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '398,866',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 9,
#      'column_index': 2,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '451,716',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 9,
#      'column_index': 3,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '470,208',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 9,
#      'column_index': 4,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '443,481',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 10,
#      'column_index': 0,
#      'row_span': 1,
#      'column_span': 1,
#      'content': 'Total Capital Assets',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 10,
#      'column_index': 1,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '398,866',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 10,
#      'column_index': 2,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '451,716',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 10,
#      'column_index': 3,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '470,208',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 10,
#      'column_index': 4,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '443,481',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 11,
#      'column_index': 0,
#      'row_span': 1,
#      'column_span': 1,
#      'content': 'Total Assets',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 11,
#      'column_index': 1,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '$ 6,668,005',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 11,
#      'column_index': 2,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '$ 6,780,851',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 11,
#      'column_index': 3,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '$ 6,649,126',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 11,
#      'column_index': 4,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '$ 5,601,544',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 12,
#      'column_index': 0,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 12,
#      'column_index': 1,
#      'row_span': 1,
#      'column_span': 4,
#      'content': "Liabilities and Shareholder's Equity",
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 13,
#      'column_index': 0,
#      'row_span': 1,
#      'column_span': 1,
#      'content': 'Current Liabilities',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 13,
#      'column_index': 1,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 13,
#      'column_index': 2,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 13,
#      'column_index': 3,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 13,
#      'column_index': 4,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 14,
#      'column_index': 0,
#      'row_span': 1,
#      'column_span': 1,
#      'content': 'Bank Indebtedness',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 14,
#      'column_index': 1,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '$ 61,769',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 14,
#      'column_index': 2,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '-',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 14,
#      'column_index': 3,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '-',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 14,
#      'column_index': 4,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '$ 298,001',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 15,
#      'column_index': 0,
#      'row_span': 1,
#      'column_span': 1,
#      'content': 'Accounts payable',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 15,
#      'column_index': 1,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '414,676',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 15,
#      'column_index': 2,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '608,139',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 15,
#      'column_index': 3,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '585,946',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 15,
#      'column_index': 4,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '404,779',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 16,
#      'column_index': 0,
#      'row_span': 1,
#      'column_span': 1,
#      'content': 'Government remittances',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 16,
#      'column_index': 1,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '197,142',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 16,
#      'column_index': 2,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '127,001',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 16,
#      'column_index': 3,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '178,339',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 16,
#      'column_index': 4,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '120,628',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 17,
#      'column_index': 0,
#      'row_span': 1,
#      'column_span': 1,
#      'content': 'Income taxes payable',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 17,
#      'column_index': 1,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '159,062',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 17,
#      'column_index': 2,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '160,390',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 17,
#      'column_index': 3,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '248,674',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 17,
#      'column_index': 4,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '3,603',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 18,
#      'column_index': 0,
#      'row_span': 1,
#      'column_span': 1,
#      'content': 'Future income taxes',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 18,
#      'column_index': 1,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '89,000',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 18,
#      'column_index': 2,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '91,000',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 18,
#      'column_index': 3,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '105,000',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 18,
#      'column_index': 4,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '95,000',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 19,
#      'column_index': 0,
#      'row_span': 1,
#      'column_span': 1,
#      'content': 'Due to shareholders',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 19,
#      'column_index': 1,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '72,663',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 19,
#      'column_index': 2,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '80,388',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 19,
#      'column_index': 3,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '80,446',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 19,
#      'column_index': 4,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '99,393',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 20,
#      'column_index': 0,
#      'row_span': 1,
#      'column_span': 1,
#      'content': 'Due to related companies',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 20,
#      'column_index': 1,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '-',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 20,
#      'column_index': 2,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '2,197,792',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 20,
#      'column_index': 3,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '750,042',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 20,
#      'column_index': 4,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '1,401,542',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 21,
#      'column_index': 0,
#      'row_span': 1,
#      'column_span': 1,
#      'content': 'Total Current Liabilities',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 21,
#      'column_index': 1,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '994,312',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 21,
#      'column_index': 2,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '3,264,710',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 21,
#      'column_index': 3,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '1,948,447',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 21,
#      'column_index': 4,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '2,423,946',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 22,
#      'column_index': 0,
#      'row_span': 1,
#      'column_span': 1,
#      'content': 'Total Liabilities',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 22,
#      'column_index': 1,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '994,312',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 22,
#      'column_index': 2,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '3,264,710',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 22,
#      'column_index': 3,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '1,948,447',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 22,
#      'column_index': 4,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '2,423,946',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 23,
#      'column_index': 0,
#      'row_span': 1,
#      'column_span': 1,
#      'content': "Shareholders' Equity",
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 23,
#      'column_index': 1,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 23,
#      'column_index': 2,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 23,
#      'column_index': 3,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 23,
#      'column_index': 4,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 24,
#      'column_index': 0,
#      'row_span': 1,
#      'column_span': 1,
#      'content': 'Capital stock',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 24,
#      'column_index': 1,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '100',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 24,
#      'column_index': 2,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '100',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 24,
#      'column_index': 3,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '100',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 24,
#      'column_index': 4,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '100',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 25,
#      'column_index': 0,
#      'row_span': 1,
#      'column_span': 1,
#      'content': 'Retained Earnings',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 25,
#      'column_index': 1,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '5,673,593',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 25,
#      'column_index': 2,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '3,516,041',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 25,
#      'column_index': 3,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '4,700,579',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 25,
#      'column_index': 4,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '3,177,498',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 26,
#      'column_index': 0,
#      'row_span': 1,
#      'column_span': 1,
#      'content': "Total Shareholder's Equity",
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 26,
#      'column_index': 1,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '5,673,693',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 26,
#      'column_index': 2,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '3,516,141',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 26,
#      'column_index': 3,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '4,700,679',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 26,
#      'column_index': 4,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '3,177,598',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 27,
#      'column_index': 0,
#      'row_span': 1,
#      'column_span': 1,
#      'content': 'Total Liabilities and',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 27,
#      'column_index': 1,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '$ 6,668,005',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 27,
#      'column_index': 2,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '$ 6,780,851',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 27,
#      'column_index': 3,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '$ 6,649,126',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 27,
#      'column_index': 4,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '$ 5,601,544',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 28,
#      'column_index': 0,
#      'row_span': 1,
#      'column_span': 1,
#      'content': "Shareholder's Equity",
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 28,
#      'column_index': 1,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 28,
#      'column_index': 2,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 28,
#      'column_index': 3,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '',
#      'page_number': 1},
#     {'kind': 'content',
#      'row_index': 28,
#      'column_index': 4,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '',
#      'page_number': 1}],
#    'page_number': 1},
#   {'row_count': 31,
#    'column_count': 5,
#    'cells': [{'kind': 'columnHeader',
#      'row_index': 0,
#      'column_index': 0,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '',
#      'page_number': 2},
#     {'kind': 'columnHeader',
#      'row_index': 0,
#      'column_index': 1,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '2022',
#      'page_number': 2},
#     {'kind': 'columnHeader',
#      'row_index': 0,
#      'column_index': 2,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '2021',
#      'page_number': 2},
#     {'kind': 'columnHeader',
#      'row_index': 0,
#      'column_index': 3,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '2020',
#      'page_number': 2},
#     {'kind': 'columnHeader',
#      'row_index': 0,
#      'column_index': 4,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '2019',
#      'page_number': 2},
#     {'kind': 'content',
#      'row_index': 1,
#      'column_index': 0,
#      'row_span': 1,
#      'column_span': 1,
#      'content': 'Sales',
#      'page_number': 2},
#     {'kind': 'content',
#      'row_index': 1,
#      'column_index': 1,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '$ 15,747,983',
#      'page_number': 2},
#     {'kind': 'content',
#      'row_index': 1,
#      'column_index': 2,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '$ 14,016,607',
#      'page_number': 2},
#     {'kind': 'content',
#      'row_index': 1,
#      'column_index': 3,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '$ 13,640,756',
#      'page_number': 2},
#     {'kind': 'content',
#      'row_index': 1,
#      'column_index': 4,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '$ 11,566,631',
#      'page_number': 2},
#     {'kind': 'content',
#      'row_index': 2,
#      'column_index': 0,
#      'row_span': 1,
# ...
#      'row_index': 25,
#      'column_index': 4,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '1,570,581',
#      'page_number': 2},
#     {'kind': 'content',
#      'row_index': 26,
#      'column_index': 0,
#      'row_span': 1,
#      'column_span': 1,
#      'content': 'Retained Earnings,',
#      'page_number': 2},
#     {'kind': 'content',
#      'row_index': 26,
#      'column_index': 1,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '3,516,041',
#      'page_number': 2},
#     {'kind': 'content',
#      'row_index': 26,
#      'column_index': 2,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '4,700,579',
#      'page_number': 2},
#     {'kind': 'content',
#      'row_index': 26,
#      'column_index': 3,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '3,177,498',
#      'page_number': 2},
#     {'kind': 'content',
#      'row_index': 26,
#      'column_index': 4,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '4,606,917',
#      'page_number': 2},
#     {'kind': 'content',
#      'row_index': 27,
#      'column_index': 0,
#      'row_span': 1,
#      'column_span': 1,
#      'content': 'beginning of year',
#      'page_number': 2},
#     {'kind': 'content',
#      'row_index': 27,
#      'column_index': 1,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '',
#      'page_number': 2},
#     {'kind': 'content',
#      'row_index': 27,
#      'column_index': 2,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '',
#      'page_number': 2},
#     {'kind': 'content',
#      'row_index': 27,
#      'column_index': 3,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '',
#      'page_number': 2},
#     {'kind': 'content',
#      'row_index': 27,
#      'column_index': 4,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '',
#      'page_number': 2},
#     {'kind': 'content',
#      'row_index': 28,
#      'column_index': 0,
#      'row_span': 1,
#      'column_span': 1,
#      'content': 'Dividends',
#      'page_number': 2},
#     {'kind': 'content',
#      'row_index': 28,
#      'column_index': 1,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '-',
#      'page_number': 2},
#     {'kind': 'content',
#      'row_index': 28,
#      'column_index': 2,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '(3,000,000)',
#      'page_number': 2},
#     {'kind': 'content',
#      'row_index': 28,
#      'column_index': 3,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '-',
#      'page_number': 2},
#     {'kind': 'content',
#      'row_index': 28,
#      'column_index': 4,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '(3,000,000)',
#      'page_number': 2},
#     {'kind': 'content',
#      'row_index': 29,
#      'column_index': 0,
#      'row_span': 1,
#      'column_span': 1,
#      'content': 'Retained Earnings, end of',
#      'page_number': 2},
#     {'kind': 'content',
#      'row_index': 29,
#      'column_index': 1,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '$ 5,673,593',
#      'page_number': 2},
#     {'kind': 'content',
#      'row_index': 29,
#      'column_index': 2,
#      'row_span': 2,
#      'column_span': 1,
#      'content': '$ 3,516,041',
#      'page_number': 2},
#     {'kind': 'content',
#      'row_index': 29,
#      'column_index': 3,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '$ 4,700,579',
#      'page_number': 2},
#     {'kind': 'content',
#      'row_index': 29,
#      'column_index': 4,
#      'row_span': 2,
#      'column_span': 1,
#      'content': '$ 3,177,498',
#      'page_number': 2},
#     {'kind': 'content',
#      'row_index': 30,
#      'column_index': 0,
#      'row_span': 1,
#      'column_span': 1,
#      'content': 'year',
#      'page_number': 2},
#     {'kind': 'content',
#      'row_index': 30,
#      'column_index': 1,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '',
#      'page_number': 2},
#     {'kind': 'content',
#      'row_index': 30,
#      'column_index': 3,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '',
#      'page_number': 2}],
#    'page_number': 2},
#   {'row_count': 4,
#    'column_count': 5,
#    'cells': [{'kind': 'columnHeader',
#      'row_index': 0,
#      'column_index': 0,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '',
#      'page_number': 3},
#     {'kind': 'columnHeader',
#      'row_index': 0,
#      'column_index': 1,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '2022',
#      'page_number': 3},
#     {'kind': 'columnHeader',
#      'row_index': 0,
#      'column_index': 2,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '2021',
#      'page_number': 3},
#     {'kind': 'columnHeader',
#      'row_index': 0,
#      'column_index': 3,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '2020',
#      'page_number': 3},
#     {'kind': 'columnHeader',
#      'row_index': 0,
#      'column_index': 4,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '2019',
#      'page_number': 3},
#     {'kind': 'content',
#      'row_index': 1,
#      'column_index': 0,
#      'row_span': 1,
#      'column_span': 1,
#      'content': 'Materials and supplies',
#      'page_number': 3},
#     {'kind': 'content',
#      'row_index': 1,
#      'column_index': 1,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '$ 38,647',
#      'page_number': 3},
#     {'kind': 'content',
#      'row_index': 1,
#      'column_index': 2,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '$ 37,560',
#      'page_number': 3},
#     {'kind': 'content',
#      'row_index': 1,
#      'column_index': 3,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '$ 47,848',
#      'page_number': 3},
#     {'kind': 'content',
#      'row_index': 1,
#      'column_index': 4,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '$ 68,467',
#      'page_number': 3},
#     {'kind': 'content',
#      'row_index': 2,
#      'column_index': 0,
#      'row_span': 1,
#      'column_span': 1,
#      'content': 'Work-in-progress',
#      'page_number': 3},
#     {'kind': 'content',
#      'row_index': 2,
#      'column_index': 1,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '741,966',
#      'page_number': 3},
#     {'kind': 'content',
#      'row_index': 2,
#      'column_index': 2,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '1,352,238',
#      'page_number': 3},
#     {'kind': 'content',
#      'row_index': 2,
#      'column_index': 3,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '483,518',
#      'page_number': 3},
#     {'kind': 'content',
#      'row_index': 2,
#      'column_index': 4,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '1,189,469',
#      'page_number': 3},
#     {'kind': 'content',
#      'row_index': 3,
#      'column_index': 0,
#      'row_span': 1,
#      'column_span': 1,
#      'content': 'Inventory, end of year',
#      'page_number': 3},
#     {'kind': 'content',
#      'row_index': 3,
#      'column_index': 1,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '780,613',
#      'page_number': 3},
#     {'kind': 'content',
#      'row_index': 3,
#      'column_index': 2,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '1,389,798',
#      'page_number': 3},
#     {'kind': 'content',
#      'row_index': 3,
#      'column_index': 3,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '$ 531,366',
#      'page_number': 3},
#     {'kind': 'content',
#      'row_index': 3,
#      'column_index': 4,
#      'row_span': 1,
#      'column_span': 1,
#      'content': '$ 1,257,936',
#      'page_number': 3}],
#    'page_number': 3}],
#  'documents': [{'bounding_regions': [{}, {}, {}],
#    'fields': {'InvoiceDate': {'content': 'December 31, 2022',
#      'bounding_regions': [{}]},
#     'Items': {'value': [{'value': {'Amount': {'value': {},
#          'content': '$ 6,280',
#          'bounding_regions': [{}]},
#         'Description': {'content': 'Cash', 'bounding_regions': [{}]}},
#        'content': 'Cash\n$ 141,943\n$ 412,649\n$ 265,566\n$ 6,280',
#        'bounding_regions': [{}]},
#       {'value': {'Amount': {'value': {},
#          'content': '1,398,480',
#          'bounding_regions': [{}]},
#         'Description': {'content': 'Accounts Receivable',
#          'bounding_regions': [{}]}},
#        'content': 'Accounts Receivable\n2,217,666\n1,817,617\n2,675,115\n1,398,480',
#        'bounding_regions': [{}]},
#       {'value': {'Amount': {'value': {},
#          'content': '1,257,936',
#          'bounding_regions': [{}]},
#         'Description': {'content': 'Inventory -note 1',
#          'bounding_regions': [{}]}},
#        'content': 'Inventory -note 1\n780,613\n1,389,798\n531,366\n1,257,936',
#        'bounding_regions': [{}]},
#       {'value': {'Amount': {'value': {},
#          'content': '2,495,367',
#          'bounding_regions': [{}]},
#         'Description': {'content': 'Due from related companies',
#          'bounding_regions': [{}]}},
#        'content': 'Due from related companies\n3,128,917\n2,709,071\n2,706,871\n2,495,367',
#        'bounding_regions': [{}]},
#       {'value': {'Amount': {'value': {},
#          'content': '443,481',
#          'bounding_regions': [{}]},
#         'Description': {'content': 'Equipment', 'bounding_regions': [{}]}},
#        'content': 'Equipment\n398,866\n451,716\n470,208\n443,481',
#        'bounding_regions': [{}]},
#       {'value': {'Amount': {'value': {},
#          'content': '$ 298,001',
#          'bounding_regions': [{}]},
#         'Description': {'content': 'Bank Indebtedness',
#          'bounding_regions': [{}]}},
#        'content': 'Bank Indebtedness\n$ 61,769\n$ 298,001\n-\n-',
#        'bounding_regions': [{}]},
#       {'value': {'Amount': {'value': {},
#          'content': '404,779',
#          'bounding_regions': [{}]},
#         'Description': {'content': 'Accounts payable',
#          'bounding_regions': [{}]}},
#        'content': 'Accounts payable\n414,676\n608,139\n585,946\n404,779',
#        'bounding_regions': [{}]},
#       {'value': {'Amount': {'value': {},
#          'content': '120,628',
#          'bounding_regions': [{}]},
#         'Description': {'content': 'Government remittances',
#          'bounding_regions': [{}]}},
#        'content': 'Government remittances\n197,142\n127,001\n178,339\n120,628',
#        'bounding_regions': [{}]},
#       {'value': {'Amount': {'value': {},
#          'content': '3,603',
#          'bounding_regions': [{}]},
#         'Description': {'content': 'Income taxes payable',
#          'bounding_regions': [{}]}},
#        'content': 'Income taxes payable\n159,062\n160,390\n248,674\n3,603',
#        'bounding_regions': [{}]},
#       {'value': {'Amount': {'value': {},
#          'content': '95,000',
#          'bounding_regions': [{}]},
#         'Description': {'content': 'Future income taxes',
#          'bounding_regions': [{}]}},
#        'content': 'Future income taxes\n89,000\n91,000\n105,000\n95,000',
#        'bounding_regions': [{}]},
#       {'value': {'Amount': {'value': {},
#          'content': '99,393',
#          'bounding_regions': [{}]},
#         'Description': {'content': 'Due to shareholders',
#          'bounding_regions': [{}]}},
#        'content': 'Due to shareholders\n72,663\n80,388\n80,446\n99,393',
#        'bounding_regions': [{}]},
#       {'value': {'Amount': {'value': {},
#          'content': '1,401,542',
#          'bounding_regions': [{}]},
#         'Description': {'content': 'Due to related companies',
#          'bounding_regions': [{}]}},
#        'content': 'Due to related companies\n2,197,792\n750,042\n1,401,542\n-',
#        'bounding_regions': [{}]},
#       {'value': {'Amount': {'value': {},
#          'content': '100',
#          'bounding_regions': [{}]},
#         'Description': {'content': 'Capital stock', 'bounding_regions': [{}]}},
#        'content': 'Capital stock\n100\n100\n100\n100',
#        'bounding_regions': [{}]},
#       {'value': {'Amount': {'value': {},
#          'content': '3,177,498',
#          'bounding_regions': [{}]},
#         'Description': {'content': 'Retained Earnings',
#          'bounding_regions': [{}]}},
#        'content': 'Retained Earnings\n5,673,593\n3,516,041\n4,700,579\n3,177,498',
#        'bounding_regions': [{}]},
#       {'value': {'Amount': {'value': {},
#          'content': '34,812',
#          'bounding_regions': [{}]},
#         'Description': {'content': 'Advertising', 'bounding_regions': [{}]}},
#        'content': 'Advertising\n59,329\n30,562\n22,542\n34,812',
#        'bounding_regions': [{}]},
#       {'value': {'Amount': {'value': {},
#          'content': '72,339',
#          'bounding_regions': [{}]},
#         'Description': {'content': 'Amortization', 'bounding_regions': [{}]}},
#        'content': 'Amortization\n104,787\n110,955\n108,595\n72,339',
#        'bounding_regions': [{}]},
#       {'value': {'Amount': {'value': {},
#          'content': '257,485',
#          'bounding_regions': [{}]},
#         'Description': {'content': 'Automotive', 'bounding_regions': [{}]}},
#        'content': 'Automotive\n473,127\n376,058\n328,939\n257,485',
#        'bounding_regions': [{}]},
#       {'value': {'Amount': {'value': {},
#          'content': '16,302',
#          'bounding_regions': [{}]},
#         'Description': {'content': 'Bank Charges', 'bounding_regions': [{}]}},
#        'content': 'Bank Charges\n15,276\n22,371\n62,571\n16,302',
#        'bounding_regions': [{}]},
#       {'value': {'Amount': {'value': {},
#          'content': '60,411',
#          'bounding_regions': [{}]},
#         'Description': {'content': 'Insurance', 'bounding_regions': [{}]}},
#        'content': 'Insurance\n74,386\n71,638\n55,243\n60,411',
#        'bounding_regions': [{}]},
#       {'value': {'Amount': {'value': {},
#          'content': '428,211',
#          'bounding_regions': [{}]},
#         'Description': {'content': 'Management Salaries',
#          'bounding_regions': [{}]}},
#        'content': 'Management Salaries\n421,465\n429,807\n412,792\n428,211',
#        'bounding_regions': [{}]},
#       {'value': {'Amount': {'value': {},
#          'content': '40,211',
#          'bounding_regions': [{}]},
#         'Description': {'content': 'Office', 'bounding_regions': [{}]}},
#        'content': 'Office\n25,601\n26,361\n43,964\n40,211',
#        'bounding_regions': [{}]},
#       {'value': {'Amount': {'value': {},
#          'content': '11,800',
#          'bounding_regions': [{}]},
#         'Description': {'content': 'Professional Fees',
#          'bounding_regions': [{}]}},
#        'content': 'Professional Fees\n13,200\n15,063\n14,253\n11,800',
#        'bounding_regions': [{}]},
#       {'value': {'Amount': {'value': {},
#          'content': '180,000',
#          'bounding_regions': [{}]},
#         'Description': {'content': 'Rent', 'bounding_regions': [{}]}},
#        'content': 'Rent\n267,333\n188,000\n180,000\n180,000',
#        'bounding_regions': [{}]},
#       {'value': {'Amount': {'value': {},
#          'content': '99,570',
#          'bounding_regions': [{}]},
#         'Description': {'content': 'Shop-Utilities, Repairs',
#          'bounding_regions': [{}]}},
#        'content': 'Shop-Utilities, Repairs\n114,764\n92,034\n68,966\n99,570',
#        'bounding_regions': [{}]},
#       {'value': {'Amount': {'value': {},
#          'content': '21,305',
#          'bounding_regions': [{}]},
#         'Description': {'content': 'Telephone', 'bounding_regions': [{}]}},
#        'content': 'Telephone\n21,332\n18,975\n19,427\n21,305',
#        'bounding_regions': [{}]},
#       {'value': {'Amount': {'value': {},
#          'content': '102,920',
#          'bounding_regions': [{}]},
#         'Description': {'content': 'Travel', 'bounding_regions': [{}]}},
#        'content': 'Travel\n201,189\n136,810\n136,153\n102,920',
#        'bounding_regions': [{}]},
#       {'value': {'Amount': {'value': {},
#          'content': '72,134',
#          'bounding_regions': [{}]},
#         'Description': {'content': 'Uniforms', 'bounding_regions': [{}]}},
#        'content': 'Uniforms\n71,769\n85,402\n71,640\n72,134',
#        'bounding_regions': [{}]},
#       {'value': {'Amount': {'value': {},
#          'content': '11,400',
#          'bounding_regions': [{}]},
#         'Description': {'content': 'Gain on foreign exchange',
#          'bounding_regions': [{}]}},
#        'content': 'Gain on foreign exchange\n11,400',
#        'bounding_regions': [{}]}],
#      'content': None},
#     'VendorName': {'content': 'ABC Company Inc.', 'bounding_regions': [{}]}}}]}
